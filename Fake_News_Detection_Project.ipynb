# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
import re
import string

# %%
data_fake = pd.read_csv('True.csv', engine='python', encoding='utf-8', on_bad_lines='skip')
data_true = pd.read_csv('Fake.csv', engine='python', encoding='utf-8', on_bad_lines='skip')

# %%
import pandas as pd

# Load the datasets while skipping malformed lines
data_fake = pd.read_csv('Fake.csv', engine='python', encoding='utf-8', on_bad_lines='skip')
data_true = pd.read_csv('True.csv', engine='python', encoding='utf-8', on_bad_lines='skip')

# Add labels
data_fake["label"] = 1  # Fake news
data_true["label"] = 0  # True news

# %%
data = pd.concat([data_fake, data_true], axis=0)

# %%
data = data.sample(frac=1).reset_index(drop=True)

# %% [markdown]
# # New Section

# %%
# Step 6: Display the first few rows
print(data.head())
# Out:
#                                                title  \
# 0  DISNEYLAND: Anti-Trump Protester Shouting “Loc...
# 1  Fewer than a third of Americans back Trump tax...
# 2  European businesses working in Russia slam pro...
# 3   Republicans Draft Platform Plank To Take Publ...
# 4   Cher Just Went Nuclear On Trump In Incredible...
#
#                                                 text       subject  \
# 0  The left continues to prove to all of us that ...      politics
# 1  WASHINGTON (Reuters) - Fewer than a third of A...  politicsNews
# 2  MOSCOW (Reuters) - The Association of European...  politicsNews
# 3  The GOP is bowing down to Cliven Bundy and his...          News
# 4  It s probably not very controversial to say th...          News
#
#                 date  label
# 0       Dec 29, 2017      1
# 1  October 24, 2017       0
# 2     July 27, 2017       0
# 3      July 14, 2016      1
# 4     April 25, 2016      1

# %%
# Shape before removing test samples
print(data_fake.shape, data_true.shape)  # ((23481, 5), (21417, 5))
# Out:
# (9494, 5) (5709, 5)

# %%
# Save the last 10 entries from each for manual testing
data_fake_manual_testing = data_fake.tail(10).copy()
data_fake = data_fake[:-10]

data_true_manual_testing = data_true.tail(10).copy()
data_true = data_true[:-10]

# %%
# Shape after removing test samples
print(data_fake.shape, data_true.shape)  # ((23471, 5), (21407, 5))
# Out:
# (9484, 5) (5699, 5)

# %%
data_fake_manual_testing['class'] = 0
data_true_manual_testing['class'] = 1

# %%
data_fake_manual_testing.head(10)
# Out:
#                                                   title  \
# 9484  IS CROOKED HILLARY Getting Ready To Compete Wi...
# 9485  FIRST LADY MELANIA TRUMP Just Set Alec Baldwin...
# 9486  BRAZILE’S BOMBSHELL BOOK Exposes How The Media...
# 9487  THEY KNEW! Donna Brazile Blows DNC Secret Wide...
# 9488  MARIA BARTIROMO Gets Into Heated Interview Wit...
# 9489  BUSTED! Proof That Trump Jr. Meeting With Russ...
# 9490  DIAMOND and SILK Have Message For GOP Candidat...
# 9491  LIBERALS ARE GOING To Be Furious Over What Thi...
# 9492  OUCH! CHUCK TODD HUMILIATES DNC Chair Over Sic...
# 9493  NEW FINDINGS SHOW TWO IMPORTANT Words Were Del...
#
#                                                    text   subject  \
# 9484  The Republican Party should be so fortunate, a...  politics
# 9485  MELANIA TRUMP never hesitates to call someone ...  politics
# 9486  Silly, silly Donna Brazile. She s publishing a...  politics
# 9487  Is there a more corrupt and power hungry group...  politics
# ...

# %%
data_true_manual_testing.head(10)
# Out:
#                                                   title  \
# 5699  U.S. warns North Korea of 'overwhelming' respo...
# 5700  Lockheed says didn't seek help from Trump's ex...
# 5701  Trump pick for China ambassador sees 'win-win'...
# 5702  Lawsuit claims Trump travel ban discriminates ...
# 5703  China says resolutely opposes deployment of TH...
# 5704  Too soon to tell how U.S. statement will affec...
# 5705  U.S. Republicans wrestle with effort to gut Ob...
# 5706  Tillerson, on first day, addresses dissent and...
# 5707  U.S., South Korea agree to deploy THAAD this y...
# 5708  Trump vows to end prohibition on church politi...
#
#                                                    text       subject  \
# 5699  SEOUL (Reuters) - U.S. President Donald Trump’...  politicsNews
# 5700  (Reuters) - Lockheed Martin Corp (LMT.N) did n...  politicsNews
# 5701  BEIJING (Reuters) - U.S. President Donald Trum...  politicsNews
# ...

# %%
# Merge the dataframes
data.reset_index(drop=True, inplace=True)


# Show the first 10 rows
data.head(10)
# Out:
#                                                title  \
# 0  DISNEYLAND: Anti-Trump Protester Shouting “Loc...
# 1  Fewer than a third of Americans back Trump tax...
# 2  European businesses working in Russia slam pro...
# 3   Republicans Draft Platform Plank To Take Publ...
# 4   Cher Just Went Nuclear On Trump In Incredible...
# 5   Editors For Two Major Outlets Would Risk Jail...
# 6   NRA Releases Fascist Ad Calling All Trump Cri...
# 7  Trump defends immigration order, says courts '...
# 8   Hillary Clinton Calls For Federal Effort To R...
# 9  Etihad advises checks with U.S. missions after...
#
#                                                 text       subject  \
# 0  The left continues to prove to all of us that ...      politics
# 1  WASHINGTON (Reuters) - Fewer than a third of A...  politicsNews
# 2  MOSCOW (Reuters) - The Association of European...  politicsNews
# 3  The GOP is bowing down to Cliven Bundy and his...          News
# ...

# %%
# Show the column names
data.columns
# Out:
# Index(['title', 'text', 'subject', 'date', 'label'], dtype='object')

# %%
# Drop unwanted columns: 'title', 'subject', 'date'
data = data.drop(['title', 'subject', 'date'], axis=1)

# %%
# Check for missing values in the remaining columns
data.isnull().sum()
# Out:
# text     0
# label    0
# dtype: int64

# %%
data = data.sample(frac=1)

# %%
data.head()
# Out:
#                                                     text  label
# 14043  If case you have not heard, Malia Obama is onc...      1
# 9114   Donald Trump has decided to make his way down ...      1
# 15010  The prospect of Donald Trump winning the presi...      1
# 9204   Donald Trump is now the unofficially declared ...      1
# 3804   A Republican candidate for a U.S. House seat i...      1

# %%
# Resetting the index after merging or modifying the data
data.reset_index(inplace=True)

# Dropping the old index column if it was added during reset
data.drop(['index'], axis=1, inplace=True)

# %%
# Displaying column names
data.columns
# Out:
# Index(['text', 'label'], dtype='object')

# %%
# Displaying first few rows of the dataset
data.head()
# Out:
#                                                 text  label
# 0  If case you have not heard, Malia Obama is onc...      1
# 1  Donald Trump has decided to make his way down ...      1
# 2  The prospect of Donald Trump winning the presi...      1
# 3  Donald Trump is now the unofficially declared ...      1
# 4  A Republican candidate for a U.S. House seat i...      1

# %%
def wordopt(text):
    text = text.lower()  # convert to lowercase
    text = re.sub('\[.*?\]', '', text)  # remove text in square brackets
    text = re.sub('\\W', ' ', text)  # remove non-word characters
    text = re.sub('https?://\S+|www\.\S+', '', text)  # remove URLs
    text = re.sub('<.*?>+', '', text)  # remove HTML tags
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)  # remove punctuation
    text = re.sub('\n', '', text)  # remove newlines
    text = re.sub('\w*\d\w*', '', text)  # remove words containing numbers
    return text

# %%
data['text'] = data['text'].apply(wordopt)

# %%
print(data.columns)
# Out:
# Index(['text', 'label'], dtype='object')

# %%
print([col for col in data.columns])
# Out:
# ['text', 'label']

# %%
data.columns = data.columns.str.strip().str.lower()

# %%
x = data['text']
y = data['label']

# %% [markdown]
# # New Section

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=0)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorization = TfidfVectorizer()
xv_train = vectorization.fit_transform(x_train)
xv_test = vectorization.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression

LR = LogisticRegression()
LR.fit(xv_train, y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score, classification_report

pred_lr = LR.predict(xv_test)
print(accuracy_score(y_test, pred_lr))
print(classification_report(y_test, pred_lr))
# Out:
# 0.9892133649039726
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99      1454
#            1       0.99      0.99      0.99      2347
#
#     accuracy                           0.99      3801
#    macro avg       0.99      0.99      0.99      3801
# weighted avg       0.99      0.99      0.99      3801

# %%
from sklearn.linear_model import LogisticRegression

LR = LogisticRegression()
LR.fit(xv_train, y_train)
# Out:
# LogisticRegression()

# %%
pred_lr = LR.predict(xv_test)

# %%
print(LR.score(xv_test, y_test))
# Out:
# 0.9892133649039726

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, pred_lr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99      1454
#            1       0.99      0.99      0.99      2347
#
#     accuracy                           0.99      3801
#    macro avg       0.99      0.99      0.99      3801
# weighted avg       0.99      0.99      0.99      3801

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import classification_report

GB = GradientBoostingClassifier(random_state=0)

# %%
GB.fit(xv_train, y_train)
# Out:
# GradientBoostingClassifier(random_state=0)

# %%
pred_gb = GB.predict(xv_test)
print(GB.score(xv_test, y_test))
print(classification_report(y_test, pred_gb))
# Out:
# 0.9984214680347278
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1454
#            1       1.00      1.00      1.00      2347
#
#     accuracy                           1.00      3801
#    macro avg       1.00      1.00      1.00      3801
# weighted avg       1.00      1.00      1.00      3801

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report

DT = DecisionTreeClassifier()
DT.fit(xv_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred_dt = DT.predict(xv_test)

# %%
print(DT.score(xv_test, y_test))
print(classification_report(y_test, pred_dt))
# Out:
# 0.9984214680347278
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1454
#            1       1.00      1.00      1.00      2347
#
#     accuracy                           1.00      3801
#    macro avg       1.00      1.00      1.00      3801
# weighted avg       1.00      1.00      1.00      3801

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report

# Train the Decision Tree model
DT = DecisionTreeClassifier()
DT.fit(xv_train, y_train)

# Make predictions
pred_dt = DT.predict(xv_test)

# Accuracy score
print(DT.score(xv_test, y_test))

# Classification report
print(classification_report(y_test, pred_dt))
# Out:
# 0.9976322020520916
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1454
#            1       1.00      1.00      1.00      2347
#
#     accuracy                           1.00      3801
#    macro avg       1.00      1.00      1.00      3801
# weighted avg       1.00      1.00      1.00      3801

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import classification_report

# Train the Gradient Boosting model
GB = GradientBoostingClassifier(random_state=0)
GB.fit(xv_train, y_train)

# Make predictions
pred_gb = GB.predict(xv_test)

# Accuracy score
print(GB.score(xv_test, y_test))

# Classification report
print(classification_report(y_test, pred_gb))
# Out:
# 0.9984214680347278
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1454
#            1       1.00      1.00      1.00      2347
#
#     accuracy                           1.00      3801
#    macro avg       1.00      1.00      1.00      3801
# weighted avg       1.00      1.00      1.00      3801

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

# Train the Random Forest model
RF = RandomForestClassifier(random_state=0)
RF.fit(xv_train, y_train)

# Make predictions
pred_rf = RF.predict(xv_test)

# Accuracy score
print(RF.score(xv_test, y_test))

# Classification report
print(classification_report(y_test, pred_rf))

# %%
def output_label(n):
    if n == 0:
        return "Fake News"
    elif n == 1:
        return "Not A Fake News"

def manual_testing(news):
    testing_news = {'text': [news]}
    new_def_test = pd.DataFrame(testing_news)
    new_def_test["text"] = new_def_test["text"].apply(wordopt)
    new_x_test = new_def_test["text"]
    new_xx_test = vectorization.transform(new_x_test)

    pred_LR = LR.predict(new_xx_test)
    pred_DT = DT.predict(new_xx_test)
    pred_GBC = GB.predict(new_xx_test)
    pred_RFC = RF.predict(new_xx_test)

    return print(
        "\nLR Prediction: {}"
        "\nDT Prediction: {}"
        "\nGBC Prediction: {}"
        "\nRFC Prediction: {}".format(
            output_label(pred_LR[0]),
            output_label(pred_DT[0]),
            output_label(pred_GBC[0]),
            output_label(pred_RFC[0])
        )
    )

# %%
news = str(input("Enter news text: "))
manual_testing(news)
